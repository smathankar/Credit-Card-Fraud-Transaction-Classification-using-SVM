# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import numpy as np
import pandas as pd
# %matplotlib inline



#dataset = pd.read_csv('creditcard.csv', sep=',',header=None)
dataset = pd.read_csv('creditcard.csv')

# %% [raw]
# # Our dataset
# plt.scatter(X[:,0], X[:,1], s=2)
# plt.show()

# %%
#dataset.count()
#dataset.describe()
#dataset.info()

ds = dataset

# %%
dataset.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
ds.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
class_label = pd.DataFrame(ds.iloc[:,-1])
class_label.columns = ['label']
ds = ds.iloc[:, :-1]

# %%
ds.head(n=5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9   ...         V20       V21       V22       V23  \
# 0  0.098698  0.363787   ...    0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425   ...   -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654   ...    0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024   ...   -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739   ...    0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount
# ...

# %%
class_label.head(n=5)
# Out:
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
#Normalizing the data

ds = ds.sub(ds.mean(axis=0), axis=1)

# %%
#Calculating covariance

df_mat = np.asmatrix(ds)
sigma = np.cov(df_mat.T)

#We have taken df_mat.T, as we are finding covariance among features of the data set.
#sigma will be our resultant covariance matrix with 4X4 dimensions.

# %%
#Finding eigen values and eigen vectors


eigVals, eigVec = np.linalg.eig(sigma)

# %%
#Sort the eigen values and eigen vectors

sorted_index = eigVals.argsort()[::-1]
eigVals = eigVals[sorted_index]
eigVec = eigVec[:,sorted_index]

# %%
#Select top k eigen values and corresponding eigen vectors

eigVec = eigVec[:,:2]

# %%
#Forming the new data set in reduced dimensions

transformed = df_mat.dot(eigVec)
transformed
# Out:
# matrix([[ 9.48138629e+04,  5.59794671e+01],
#         [ 9.48138546e+04, -9.09536597e+01],
#         [ 9.48128757e+04,  2.85024840e+02],
#         ...,
#         [-7.79741415e+04, -1.61186800e+01],
#         [-7.79741447e+04, -7.39987151e+01],
#         [-7.79781331e+04,  1.33004366e+02]])

# %%
#horizontally stack transformed data set with class label.
final_df = np.hstack((transformed, class_label))
#convert the numpy array to data frame
final_df = pd.DataFrame(final_df)
#define the column names
final_df.columns = ['x','y','label']

# %%
final_df.head(n=5)
# Out:
#               x           y  label
# 0  94813.862881   55.979467    0.0
# 1  94813.854640  -90.953660    0.0
# 2  94812.875662  285.024840    0.0
# 3  94812.861396   29.859853    0.0
# 4  94811.858408  -23.652028    0.0

# %%
dataset.tail(5)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...         V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...    0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...    0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...    0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...    0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...    0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
#Plotting the new data set

groups = final_df.groupby('label')
figure, axes = plt.subplots()
axes.margins(0.05)
for name, group in groups:
    axes.plot(group.x, group.y, marker='o', linestyle='', ms=6, label=name)
    axes.set_title("PCA     0 = 'Non Fraudulant', 1 = 'Fraudulant'")
axes.legend()
plt.xlabel("principal component 1")
plt.ylabel("principal component 2")
plt.show()

# %%
data = final_df

data1 = np.array(data[['label']])
data2 = np.array(data[['x','y']])

# %% [markdown]
# #final_df.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
# final_df.hist()
# plt.show

# %%
final_df
# Out:
#                    x           y  label
# 0       94813.862881   55.979467    0.0
# 1       94813.854640  -90.953660    0.0
# 2       94812.875662  285.024840    0.0
# 3       94812.861396   29.859853    0.0
# 4       94811.858408  -23.652028    0.0
# 5       94811.854708  -89.974022    0.0
# 6       94809.854754  -88.652573    0.0
# 7       94806.856760  -52.843666    0.0
# 8       94806.859674   -0.441327    0.0
# 9       94804.854702  -89.964132    0.0
# 10      94803.854934  -85.840206    0.0
# 11      94803.855014  -83.653127    0.0
# 12      94803.861273   27.860297    0.0
# 13      94802.856028  -66.142240    0.0
# 14      94801.857801  -34.836766    0.0
# 15      94801.855405  -77.652175    0.0
# 16      94801.855226  -80.652060    0.0
# 17      94800.854536  -92.753695    0.0
# 18      94799.857115  -46.827241    0.0
# 19      94798.854769  -88.640170    0.0
# 20      94797.867437  138.072108    0.0
# 21      94796.856396  -59.551875    0.0
# ...

# %% [markdown]
# # SVM with SckitLearn

# %%
fdf = pd.DataFrame(final_df)

# %%
fdf = fdf[(fdf.label == 1.0)].append(fdf.tail(50000))
#fdf = fdf[(fdf.label == 1.0)].append(fdf.tail(10000))
fdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50492 entries, 541 to 284806
# Data columns (total 3 columns):
# x        50492 non-null float64
# y        50492 non-null float64
# label    50492 non-null float64
# dtypes: float64(3)
# memory usage: 1.5 MB

# %%
from sklearn.model_selection import train_test_split as tts
#array = np.array(fdf)
X = fdf[['x', 'y']]
Y = fdf[['label']]
seed = 10

X_train, X_test, Y_train, Y_test = tts(X, Y, test_size=0.20, random_state=seed)

# %%
from sklearn.svm import SVC

svm = SVC(C=1.0, kernel='rbf', degree=2, gamma="auto", random_state=None)
#svm = SVC(C=1.0, kernel='linear')
model = svm.fit(X_train, Y_train)
model
Y_prediction = svm.predict(X_test)
# Out:
# C:\Users\shubham\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(Y_test, Y_prediction))
print(classification_report(Y_test, Y_prediction))
plt.matshow(confusion_matrix(Y_test, Y_prediction))
plt.colorbar()
# Out:
# [[9981    3]
#  [  90   25]]
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      9984
#         1.0       0.89      0.22      0.35       115
#
# avg / total       0.99      0.99      0.99     10099
